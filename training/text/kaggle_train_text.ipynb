# %% [markdown]
# # Kavach — DistilBERT text-classifier training
#
# **Before Run All:** in the right sidebar set **Accelerator = GPU T4** and **Internet = On**.
#
# Runs: clone repo → install deps → build corpus → fine-tune DistilBERT → zip artifacts.
# When finished, download `distilbert_artifacts.zip` from the Output panel and unzip it into `models/` in your local repo.

# %%
import os
if not os.path.exists('/kaggle/working/kavach'):
    # !git clone https://github.com/23f2001033/kavach.git /kaggle/working/kavach
# %cd /kaggle/working/kavach
# !git pull

# %%
# !pip install -q -U datasets scikit-learn transformers onnx

# %%
# !python -m data_pipeline.build_corpus

# %%
# !python training/text/train_transformer.py --windowed --epochs 3

# %%
# !zip -r /kaggle/working/distilbert_artifacts.zip training/text/output/distilbert
print('DONE — download distilbert_artifacts.zip from the Output panel')
